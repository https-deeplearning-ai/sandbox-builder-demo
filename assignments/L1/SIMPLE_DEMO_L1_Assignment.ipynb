# %% [markdown]
# ## Replace dummy submission with actual assignment

# %%
# GRADED FUNCTION: learner_func


def learner_func():
    # return the literal string "hello world"

    ### START CODE HERE ###
    pass
    ### END CODE HERE ###

# %%
# GRADED FUNCTION: add


def add(a, b):
    # return the sum of a and b

    ### START CODE HERE ###
    pass
    ### END CODE HERE ###
