# %% [markdown]
# ## This is L2 exam

# %%
# GRADED FUNCTION: simple_output


def simple_output():
    # return the literal string "hihi"

    ### START CODE HERE ###
    return "hihi"  # @OMIT
    ### END CODE HERE ###

# %%
# GRADED FUNCTION: multiply


def multiply(a, b):
    # return the product of a and b

    ### START CODE HERE ###
    return a * b  # @OMIT
    ### END CODE HERE ###
